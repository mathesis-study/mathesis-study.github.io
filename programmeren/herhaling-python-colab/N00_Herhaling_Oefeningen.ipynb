# %% [markdown]
# # Oefening 1
#
# **Opgave.** Een pizza kost $12.50$ euro. Bereken wat $7$ pizza’s kosten met $10\%$ korting, en toon het bedrag afgerond op $2$ cijfers na de komma. Gebruik één enkele expressie.

# %%
round(12.50 * ... * (1 - ...), 2)

# %% [markdown]
# ## Oefening 2
#
# **Opgave.** Je hebt `x = 3` en `y = 8`. Wissel de waarden om, zodat `x` gelijk is aan $8$ en `y` aan $3$. Je mag de getallen niet opnieuw intypen.

# %%
x = 3
y = 8
# wissel hier de waarden om
...
print(x, y)   # moet 8 3 tonen

# %% [markdown]
# ## Oefening 3
#
# **Opgave.** Vraag de gebruiker twee kommagetallen en toon het grootste van de twee, afgerond op $1$ cijfer na de komma.

# %%
a = float(input("Eerste getal: "))
b = ...
grootste = ...
print("Het grootste is", round(..., 1))

# %% [markdown]
# ## Oefening 4
#
# **Opgave.** Vraag een punt op $20$. Toon *niet geslaagd* onder $10$, *geslaagd* vanaf $10$, en *geslaagd met onderscheiding* vanaf $14$.

# %%
punt = int(input("Punt op 20: "))
if ...:
    print(...)
elif ...:
    print(...)
else:
    print(...)

# %% [markdown]
# ## Oefening 5
#
# **Opgave.** Toon de tafel van $7$, van $7 \times 1$ tot en met $7 \times 10$, in de vorm `7 x 3 = 21`.

# %%
for i in range(...):
    print(7, "x", i, "=", ...)

# %% [markdown]
# ## Oefening 6
#
# **Opgave.** Vraag getallen aan de gebruiker tot die `0` intypt. Toon daarna de som van alle ingegeven getallen.

# %%
totaal = 0
getal = int(input("Getal (0 = stoppen): "))
while ...:
    totaal ...
    getal = ...
print("Som:", totaal)

# %% [markdown]
# ## Oefening 7
#
# **Opgave.** De computer denkt aan het getal $7$. Laat de gebruiker raden tot het juist is, zeg telkens *te hoog* of *te laag*, en toon op het einde het aantal pogingen.

# %%
geheim = 7
pogingen = 1
gok = int(input("Raad: "))
while ...:
    if ...:
        print("Te hoog")
    else:
        print("Te laag")
    gok = ...
    pogingen ...
print("Juist na", pogingen)
